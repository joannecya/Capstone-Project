# %%
import re

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#from feature_engineering import create_time_matrix
#from MatchingAlgorithm import run_algorithm

# %%
#X = np.array(orders['lat'])
#Y = np.array(orders['long'])

# generate random integer values
from random import seed
from random import randint
seed(123)
x =[]
y=[]
sequence = [i for i in range(20)]
# make choices from the sequence
for i in range(10):
 selection = randint(0, 10)
 selection2 = randint(0, 10)
 x+=[selection]
 y+=[selection2]
print(x)
print(y)
# Out:
# [0, 1, 4, 0, 8, 5, 0, 2, 8, 3]
# [4, 6, 1, 6, 8, 5, 2, 5, 5, 2]

# %%
#size of grid
plt.rcParams["figure.figsize"] = [10,10]
plt.rcParams["figure.autolayout"] = True
#points to plot
""" x = np.array(orders['lat'])
y = np.array(orders['long']) """

""" plt.xlim(0, 10)
plt.ylim(0, 10) """
""" plt.axis([23, 24, 74, 75]) """
plt.grid() # to show grid lines
""" plt.plot(x, y, marker="o", markersize=50, markeredgecolor="red", markerfacecolor="green") """
plt.plot(x, y, 'r*',marker="o", markerfacecolor="blue")
for i,j in zip(x,y):
    plt.text(i,j, '({},{})'.format(i,j))

plt.show()
